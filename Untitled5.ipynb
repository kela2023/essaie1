# %% [markdown]
# <a href="https://colab.research.google.com/github/kela2023/essaie1/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# les bibliotheques utiles
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

import cv2
import requests
import matplotlib.image as mpimg
import sys
import datetime
 

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib
data_dir = tf.keras.utils.get_file(
    "test.zip",
    "https://github.com/kela2023/train_images/raw/main/test.zip?raw=true",
    extract=False)

import zipfile
with zipfile.ZipFile(data_dir, 'r') as zip_ref:
    zip_ref.extractall('/content/datasets')

data_dir = pathlib.Path('/content/datasets/test')
print(data_dir)
print(os.path.abspath(data_dir))
# Out:
# /content/datasets/test
# /content/datasets/test

# %%
image_count = len(list(data_dir.glob('*/*')))
print(image_count)
# Out:
# 32

# %%
batch_size = 3
img_height = 200
img_width = 200

train_data = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=42,
  image_size=(img_height, img_width),
  batch_size=batch_size,
  )

val_data = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=42,
  image_size=(img_height, img_width),
  batch_size=batch_size)

class_names = val_data.class_names
print(class_names)
# Out:
# Found 32 files belonging to 2 classes.
# Using 26 files for training.
# Found 32 files belonging to 2 classes.
# Using 6 files for validation.
# ['rihanna', 'will']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_data.take(1):
  for i in range(3):
    ax = plt.subplot(1, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
num_classes = 2

model = tf.keras.Sequential([
    layers.experimental.preprocessing.Rescaling(1./255),
    layers.Conv2D(128,4, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64,4, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32,4, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(16,4, activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(64,activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])

model.compile(optimizer='adam',
              loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'],)

logdir="logs"

tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir,histogram_freq=1, write_images=logdir,
                                                   embeddings_data=train_data)

model.fit( 
    train_data,
  validation_data=val_data,
  epochs=2,
  callbacks=[tensorboard_callback]
)
# Out:
# WARNING:tensorflow:`embeddings_data` is not supported in TensorFlow 2.0. Instead, all `Embedding` variables will be visualized.
# Epoch 1/2
# /usr/local/lib/python3.9/dist-packages/keras/backend.py:5585: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 9/9 [==============================] - 15s 1s/step - loss: 0.7327 - accuracy: 0.3846 - val_loss: 0.6987 - val_accuracy: 0.3333
# Epoch 2/2
# 9/9 [==============================] - 12s 1s/step - loss: 0.6907 - accuracy: 0.5385 - val_loss: 0.6913 - val_accuracy: 0.6667

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  rescaling_1 (Rescaling)     (None, 200, 200, 3)       0
#
#  conv2d_4 (Conv2D)           (None, 197, 197, 128)     6272
#
#  max_pooling2d_4 (MaxPooling  (None, 98, 98, 128)      0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 95, 95, 64)        131136
#
#  max_pooling2d_5 (MaxPooling  (None, 47, 47, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 44, 44, 32)        32800
#
#  max_pooling2d_6 (MaxPooling  (None, 22, 22, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 19, 19, 16)        8208
#
#  max_pooling2d_7 (MaxPooling  (None, 9, 9, 16)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1296)              0
#
#  dense_2 (Dense)             (None, 64)                83008
#
#  dense_3 (Dense)             (None, 2)                 130
#
# ...
# Total params: 261,554
# Trainable params: 261,554
# ...

# %%
# %pylab inline


data_dir1 = r"https://github.com/kela2023/train_images/blob/main/test/rihanna/83d263a9b7ce46aaebb7791e14919b00.jpg?raw=true"
resp = requests.get(data_dir1, stream=True).raw
image_array= np.asarray(bytearray(resp.read()), dtype="uint8")
print(f'Shape of the image {image_array.shape}')
rihanna = cv2.imdecode(image_array, cv2.IMREAD_COLOR)
plt.axis('off')
plt.imshow(cv2.cvtColor(rihanna, cv2.COLOR_BGR2RGB)) 
plt.show()


data_dir2 = r"https://github.com/kela2023/train_images/blob/main/test/will/1392549-l-acteur-will-smith.jpg?raw=true"
resp = requests.get(data_dir2, stream=True).raw
image_array_r= np.asarray(bytearray(resp.read()), dtype="uint8")
print(f'Shape of the image {image_array_r.shape}')
will= cv2.imdecode(image_array_r, cv2.IMREAD_COLOR)
plt.axis('off')
plt.imshow(cv2.cvtColor(will, cv2.COLOR_BGR2RGB)) 
plt.show()


from google.colab import files
file_to_predict = files.upload()
for file_ in file_to_predict:
    image_to_predict = cv2.imread(file_,cv2.IMREAD_COLOR)
    plt.imshow(cv2.cvtColor(image_to_predict, cv2.COLOR_BGR2RGB))
    plt.show()
    img_to_predict = np.expand_dims(cv2.resize(image_to_predict,(200,200)), axis=0) 
    predict_x=model.predict(img_to_predict) 
    res = np.argmax(predict_x,axis=1)
    print(res)
    print(model.predict(img_to_predict))
    if res == 1:
        plt.imshow(cv2.cvtColor(rihanna, cv2.COLOR_BGR2RGB))
        plt.show()
        print("IT'S A RIHANNA !")
    elif res == 0 :
        plt.imshow(cv2.cvtColor(will, cv2.COLOR_BGR2RGB))
        plt.show()
        print("IT'S A WILL !")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Shape of the image (56515,)
# Shape of the image (815100,)
#      <input type="file" id="files-e49ca882-e32f-45c5-a4e3-eb84276e16eb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e49ca882-e32f-45c5-a4e3-eb84276e16eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...
